# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('C:/Users/tanis/Downloads/consumer_electronics_sales_data.csv')

# %%
df
# Out:
#       ProductID ProductCategory  ProductBrand  ProductPrice  CustomerAge  \
# 0          5874     Smartphones  Other Brands    312.949668           18
# 1          5875   Smart Watches       Samsung    980.389404           35
# 2          5876         Tablets       Samsung   2606.718293           63
# 3          5877     Smartphones       Samsung    870.395450           63
# 4          5878         Tablets          Sony   1798.955875           57
# ...         ...             ...           ...           ...          ...
# 8995      14869   Smart Watches       Samsung   1041.149163           36
# 8996      14870     Smartphones       Samsung   1485.694311           57
# 8997      14871      Headphones       Samsung   2887.369597           28
# 8998      14872         Tablets            HP   1490.453964           38
# 8999      14873     Smartphones          Sony   2315.583087           62
#
#       CustomerGender  PurchaseFrequency  CustomerSatisfaction  PurchaseIntent
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9000 entries, 0 to 8999
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ProductID             9000 non-null   int64
#  1   ProductCategory       9000 non-null   object
#  2   ProductBrand          9000 non-null   object
#  3   ProductPrice          9000 non-null   float64
#  4   CustomerAge           9000 non-null   int64
#  5   CustomerGender        9000 non-null   int64
#  6   PurchaseFrequency     9000 non-null   int64
#  7   CustomerSatisfaction  9000 non-null   int64
#  8   PurchaseIntent        9000 non-null   int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 632.9+ KB

# %%
df.describe()
# Out:
#           ProductID  ProductPrice  CustomerAge  CustomerGender  \
# count   9000.000000   9000.000000  9000.000000     9000.000000
# mean   10373.500000   1527.429195    43.347000        0.508889
# std     2598.220545    829.900898    15.055084        0.499949
# min     5874.000000    100.376358    18.000000        0.000000
# 25%     8123.750000    809.165014    30.000000        0.000000
# 50%    10373.500000   1513.024577    43.000000        1.000000
# 75%    12623.250000   2244.415520    56.000000        1.000000
# max    14873.000000   2999.852253    69.000000        1.000000
#
#        PurchaseFrequency  CustomerSatisfaction  PurchaseIntent
# count        9000.000000           9000.000000     9000.000000
# mean           10.054667              2.996000        0.566444
# std             5.461328              1.405301        0.495593
# min             1.000000              1.000000        0.000000
# 25%             5.000000              2.000000        0.000000
# ...

# %%
df.isnull().sum()
# Out:
# ProductID               0
# ProductCategory         0
# ProductBrand            0
# ProductPrice            0
# CustomerAge             0
# CustomerGender          0
# PurchaseFrequency       0
# CustomerSatisfaction    0
# PurchaseIntent          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#       ProductID ProductCategory  ProductBrand  ProductPrice  CustomerAge  \
# 0          5874     Smartphones  Other Brands    312.949668           18
# 1          5875   Smart Watches       Samsung    980.389404           35
# 2          5876         Tablets       Samsung   2606.718293           63
# 3          5877     Smartphones       Samsung    870.395450           63
# 4          5878         Tablets          Sony   1798.955875           57
# ...         ...             ...           ...           ...          ...
# 8995      14869   Smart Watches       Samsung   1041.149163           36
# 8996      14870     Smartphones       Samsung   1485.694311           57
# 8997      14871      Headphones       Samsung   2887.369597           28
# 8998      14872         Tablets            HP   1490.453964           38
# 8999      14873     Smartphones          Sony   2315.583087           62
#
#       CustomerGender  PurchaseFrequency  CustomerSatisfaction  PurchaseIntent
# ...

# %%
df['ProductCategory'].unique()
# Out:
# array(['Smartphones', 'Smart Watches', 'Tablets', 'Laptops', 'Headphones'],
#       dtype=object)

# %%
df['ProductCategory']=df['ProductCategory'].map({'Smartphones':0,'Smart Watches':1,'Tablets':2,'Laptops':3,'Headphones':4})

# %%
df = df.drop(columns=['ProductBrand'])

# %%
df
# Out:
#       ProductID  ProductCategory  ProductPrice  CustomerAge  CustomerGender  \
# 0          5874                0    312.949668           18               0
# 1          5875                1    980.389404           35               1
# 2          5876                2   2606.718293           63               0
# 3          5877                0    870.395450           63               1
# 4          5878                2   1798.955875           57               0
# ...         ...              ...           ...          ...             ...
# 8995      14869                1   1041.149163           36               1
# 8996      14870                0   1485.694311           57               0
# 8997      14871                4   2887.369597           28               0
# 8998      14872                2   1490.453964           38               0
# 8999      14873                0   2315.583087           62               0
#
# ...

# %%
df.isnull().sum()
# Out:
# ProductID               0
# ProductCategory         0
# ProductPrice            0
# CustomerAge             0
# CustomerGender          0
# PurchaseFrequency       0
# CustomerSatisfaction    0
# PurchaseIntent          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (9000, 8)

# %%
df.corr()
# Out:
#                       ProductID  ProductCategory  ProductPrice  CustomerAge  \
# ProductID              1.000000         0.005114      0.022327    -0.005579
# ProductCategory        0.005114         1.000000      0.027057    -0.015843
# ProductPrice           0.022327         0.027057      1.000000    -0.009322
# CustomerAge           -0.005579        -0.015843     -0.009322     1.000000
# CustomerGender         0.017049        -0.012814      0.001835    -0.010767
# PurchaseFrequency      0.012688         0.023870      0.009281     0.005746
# CustomerSatisfaction  -0.001504        -0.000263      0.002112     0.003753
# PurchaseIntent        -0.006596        -0.023081     -0.017512     0.289798
#
#                       CustomerGender  PurchaseFrequency  CustomerSatisfaction  \
# ProductID                   0.017049           0.012688             -0.001504
# ProductCategory            -0.012814           0.023870             -0.000263
# ...

# %%
df.describe()
# Out:
#           ProductID  ProductCategory  ProductPrice  CustomerAge  \
# count   9000.000000      9000.000000   9000.000000  9000.000000
# mean   10373.500000         1.980667   1527.429195    43.347000
# std     2598.220545         1.412902    829.900898    15.055084
# min     5874.000000         0.000000    100.376358    18.000000
# 25%     8123.750000         1.000000    809.165014    30.000000
# 50%    10373.500000         2.000000   1513.024577    43.000000
# 75%    12623.250000         3.000000   2244.415520    56.000000
# max    14873.000000         4.000000   2999.852253    69.000000
#
#        CustomerGender  PurchaseFrequency  CustomerSatisfaction  PurchaseIntent
# count     9000.000000        9000.000000           9000.000000     9000.000000
# mean         0.508889          10.054667              2.996000        0.566444
# std          0.499949           5.461328              1.405301        0.495593
# ...

# %%
df.max()
# Out:
# ProductID               14873.000000
# ProductCategory             4.000000
# ProductPrice             2999.852253
# CustomerAge                69.000000
# CustomerGender              1.000000
# PurchaseFrequency          19.000000
# CustomerSatisfaction        5.000000
# PurchaseIntent              1.000000
# dtype: float64

# %%
sns.barplot(x='CustomerGender',y='CustomerSatisfaction',data=df)
# Out:
# <Axes: xlabel='CustomerGender', ylabel='CustomerSatisfaction'>

# %%
sns.barplot(x='CustomerGender',y='PurchaseFrequency',data=df)
# Out:
# <Axes: xlabel='CustomerGender', ylabel='PurchaseFrequency'>

# %%
sns.barplot(x='CustomerGender',y='PurchaseIntent',data=df)
# Out:
# <Axes: xlabel='CustomerGender', ylabel='PurchaseIntent'>

# %%
sns.barplot(x='CustomerGender',y='PurchaseFrequency',data=df)
# Out:
# <Axes: xlabel='CustomerGender', ylabel='PurchaseFrequency'>

# %%
sns.pairplot(df)
# Out:
# C:\Users\tanis\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\tanis\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\tanis\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.regplot(x='CustomerGender',y='PurchaseFrequency',data=df)
# Out:
# <Axes: xlabel='CustomerGender', ylabel='PurchaseFrequency'>

# %%
df
# Out:
#       ProductID  ProductCategory  ProductPrice  CustomerAge  CustomerGender  \
# 0          5874                0    312.949668           18               0
# 1          5875                1    980.389404           35               1
# 2          5876                2   2606.718293           63               0
# 3          5877                0    870.395450           63               1
# 4          5878                2   1798.955875           57               0
# ...         ...              ...           ...          ...             ...
# 8995      14869                1   1041.149163           36               1
# 8996      14870                0   1485.694311           57               0
# 8997      14871                4   2887.369597           28               0
# 8998      14872                2   1490.453964           38               0
# 8999      14873                0   2315.583087           62               0
#
# ...

# %%
sns.boxplot(x='ProductID',color='g',data = df)
# Out:
# <Axes: xlabel='ProductID'>

# %%
sns.boxplot(x='ProductCategory',color='g',data = df)
# Out:
# <Axes: xlabel='ProductCategory'>

# %%
sns.boxplot(x='ProductPrice',color='g',data = df)
# Out:
# <Axes: xlabel='ProductPrice'>

# %%
sns.boxplot(x='CustomerAge',color='g',data = df)
# Out:
# <Axes: xlabel='CustomerAge'>

# %%
sns.boxplot(x='CustomerGender',color='g',data = df)
# Out:
# <Axes: xlabel='CustomerGender'>

# %%
sns.boxplot(x='PurchaseFrequency',color='g',data = df)
# Out:
# <Axes: xlabel='PurchaseFrequency'>

# %%
sns.boxplot(x='CustomerSatisfaction',color='g',data = df)
# Out:
# <Axes: xlabel='CustomerSatisfaction'>

# %%
sns.boxplot(x='PurchaseIntent',color='g',data = df)
# Out:
# <Axes: xlabel='PurchaseIntent'>

# %%
X=df.iloc[:,0:7]
Y=df.iloc[:,-1]

# %%
X
# Out:
#       ProductID  ProductCategory  ProductPrice  CustomerAge  CustomerGender  \
# 0          5874                0    312.949668           18               0
# 1          5875                1    980.389404           35               1
# 2          5876                2   2606.718293           63               0
# 3          5877                0    870.395450           63               1
# 4          5878                2   1798.955875           57               0
# ...         ...              ...           ...          ...             ...
# 8995      14869                1   1041.149163           36               1
# 8996      14870                0   1485.694311           57               0
# 8997      14871                4   2887.369597           28               0
# 8998      14872                2   1490.453964           38               0
# 8999      14873                0   2315.583087           62               0
#
#       PurchaseFrequency  CustomerSatisfaction
# ...

# %%
Y
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       0
#        ..
# 8995    0
# 8996    1
# 8997    0
# 8998    1
# 8999    1
# Name: PurchaseIntent, Length: 9000, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.10, random_state=320)

# %%
X_train
# Out:
#       ProductID  ProductCategory  ProductPrice  CustomerAge  CustomerGender  \
# 1323       7197                4   2159.832638           31               0
# 1865       7739                2   1455.262809           63               0
# 4823      10697                3   1607.368184           39               1
# 6779      12653                0   1736.119482           31               0
# 7605      13479                4   2705.982429           53               1
# ...         ...              ...           ...          ...             ...
# 781        6655                3    623.683710           23               1
# 1157       7031                0   2571.682754           54               0
# 5724      11598                2   1946.720189           35               1
# 1802       7676                2   2248.287456           28               1
# 6850      12724                3   2274.074568           67               0
#
#       PurchaseFrequency  CustomerSatisfaction
# ...

# %%
X
# Out:
#       ProductID  ProductCategory  ProductPrice  CustomerAge  CustomerGender  \
# 0          5874                0    312.949668           18               0
# 1          5875                1    980.389404           35               1
# 2          5876                2   2606.718293           63               0
# 3          5877                0    870.395450           63               1
# 4          5878                2   1798.955875           57               0
# ...         ...              ...           ...          ...             ...
# 8995      14869                1   1041.149163           36               1
# 8996      14870                0   1485.694311           57               0
# 8997      14871                4   2887.369597           28               0
# 8998      14872                2   1490.453964           38               0
# 8999      14873                0   2315.583087           62               0
#
#       PurchaseFrequency  CustomerSatisfaction
# ...

# %%
X_test
# Out:
#       ProductID  ProductCategory  ProductPrice  CustomerAge  CustomerGender  \
# 1635       7509                2   1808.933272           34               0
# 5622      11496                3   1546.300484           63               1
# 7833      13707                0   2350.723779           68               0
# 8338      14212                1   2247.797177           45               0
# 2683       8557                3   1372.347158           35               0
# ...         ...              ...           ...          ...             ...
# 8970      14844                1   1424.286319           62               0
# 7782      13656                1   1558.308690           53               0
# 4469      10343                2   1390.395398           45               0
# 1959       7833                2   2452.175071           67               1
# 5927      11801                4   2413.977673           60               0
#
#       PurchaseFrequency  CustomerSatisfaction
# ...

# %%
Y_train
# Out:
# 1323    0
# 1865    1
# 4823    1
# 6779    0
# 7605    1
#        ..
# 781     0
# 1157    1
# 5724    1
# 1802    0
# 6850    1
# Name: PurchaseIntent, Length: 8100, dtype: int64

# %%
Y_test
# Out:
# 1635    0
# 5622    1
# 7833    0
# 8338    1
# 2683    0
#        ..
# 8970    0
# 7782    0
# 4469    1
# 1959    1
# 5927    0
# Name: PurchaseIntent, Length: 900, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler

# %%
# Split the dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Initialize the Logistic Regression classifier
log_reg = LogisticRegression(max_iter=200)

# %%
# Train the classifier
log_reg.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=200)

# %%
# Make predictions
y_pred = log_reg.predict(X_test)

# %%
# Evaluate the classifier
print("Logistic_regression_accuracy:", accuracy_score(Y_test, y_pred))
print("Logistic_regression_classification Report:\n", classification_report(Y_test, y_pred))
# Out:
# Logistic_regression_accuracy: 0.8527777777777777
# Logistic_regression_classification Report:
#                precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83       793
#            1       0.86      0.88      0.87      1007
#
#     accuracy                           0.85      1800
#    macro avg       0.85      0.85      0.85      1800
# weighted avg       0.85      0.85      0.85      1800

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
#postpruning technique
treemodel=DecisionTreeClassifier(max_depth=2)

# %%
#treemodel
treemodel.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %%
#constructing a tree
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(treemodel,filled=True)
# Out:
# [Text(0.5, 0.8333333333333334, 'x[4] <= -0.021\ngini = 0.491\nsamples = 7200\nvalue = [3109, 4091]'),
#  Text(0.25, 0.5, 'x[6] <= 0.359\ngini = 0.43\nsamples = 3525\nvalue = [2424, 1101]'),
#  Text(0.125, 0.16666666666666666, 'gini = 0.095\nsamples = 2150\nvalue = [2043, 107]'),
#  Text(0.375, 0.16666666666666666, 'gini = 0.401\nsamples = 1375\nvalue = [381, 994]'),
#  Text(0.75, 0.5, 'x[3] <= -0.86\ngini = 0.303\nsamples = 3675\nvalue = [685, 2990]'),
#  Text(0.625, 0.16666666666666666, 'gini = 0.482\nsamples = 949\nvalue = [565, 384]'),
#  Text(0.875, 0.16666666666666666, 'gini = 0.084\nsamples = 2726\nvalue = [120, 2606]')]

# %%
#prediction
Y_pred=treemodel.predict(X_test)

# %%
Y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
score=accuracy_score(Y_pred,Y_test)

# %%
print(score)
# Out:
# 0.8588888888888889

# %%
#prepruning
parameter={'criterion':['ginni','entrophy','log_loss'],
          'splitter':['best','random'],
          'max_depth':[1,2,3,4,5],
          'max_features':['auto','sqrt','log2'],
          'ccp_alpha':[1,2,3,4,5,6,7]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
treemodel=DecisionTreeClassifier()
cv=GridSearchCV(treemodel,param_grid=parameter,cv=5,
               scoring='accuracy')

# %%
cv.fit(X_train,Y_train)
# Out:
# C:\Users\tanis\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\tanis\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\tanis\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
#   warnings.warn(
# C:\Users\tanis\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:269: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'`.
# ...

# %%
cv.best_params_
# Out:
# {'ccp_alpha': 1,
#  'criterion': 'log_loss',
#  'max_depth': 1,
#  'max_features': 'auto',
#  'splitter': 'best'}

# %%
cv.predict(X_test)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
Y_pred=cv.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
Decision_tree_accuracy= accuracy_score(Y_pred,Y_test)
print(Decision_tree_accuracy)
# Out:
# 0.5594444444444444

# %%
print(classification_report(Y_pred,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       1.00      0.56      0.72      1800
#
#     accuracy                           0.56      1800
#    macro avg       0.50      0.28      0.36      1800
# weighted avg       1.00      0.56      0.72      1800
# C:\Users\tanis\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\tanis\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
#visualization
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
randomforest = RandomForestClassifier()

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.20, random_state=43)

# %%
from sklearn.model_selection import GridSearchCV

param_dist = {'max_depth': [2,3,4,5],
             'bootstrap':[True,False],
             'max_features': ['auto','sqrt','log2',None],
              'criterion':['gini','entropy']}

# %%
classifier_regressor = GridSearchCV(randomforest,
                                    param_grid = param_dist,
                                    cv=5,
                                   n_jobs=3)

# %%
randomforest.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
#prediction
Y_pred =randomforest.predict(X_test)
Y_pred
# Out:
# array([1, 0, 0, ..., 0, 0, 1], dtype=int64)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
Random_Forest_accuracy = accuracy_score(Y_pred,Y_test)
print(Random_Forest_accuracy)
# Out:
# 0.9583333333333334

# %%
print(classification_report(Y_pred,Y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.94      0.95       786
#            1       0.96      0.97      0.96      1014
#
#     accuracy                           0.96      1800
#    macro avg       0.96      0.96      0.96      1800
# weighted avg       0.96      0.96      0.96      1800

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier()

# %%
#make prediction
y_pred = knn.predict(X_test)

# %%
# Evaluate the classifier
print("KNN Accuracy:", accuracy_score(Y_test, y_pred))
print("KNN Classification Report:\n", classification_report(Y_test, y_pred))
# Out:
# KNN Accuracy: 0.5116666666666667
# KNN Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.42      0.38      0.40       773
#            1       0.57      0.61      0.59      1027
#
#     accuracy                           0.51      1800
#    macro avg       0.50      0.50      0.49      1800
# weighted avg       0.51      0.51      0.51      1800

# %%
from sklearn.svm import SVC

# %%
# Initialize the SVM classifier
svm = SVC(kernel='linear')

# %%
svm.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
# Make predictions
y_pred = svm.predict(X_test)

# %%
# Evaluate the classifier
print("SVM Accuracy:", accuracy_score(Y_test, y_pred))
print("SVM Classification Report:\n", classification_report(Y_test, y_pred))
# Out:
# SVM Accuracy: 0.8566666666666667
# SVM Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.84      0.83      0.83       773
#            1       0.87      0.88      0.88      1027
#
#     accuracy                           0.86      1800
#    macro avg       0.85      0.85      0.85      1800
# weighted avg       0.86      0.86      0.86      1800

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[382], line 2
#       1 scores={'Model':['Logistic Regression','Decision Tree Regressor','Random Forest Regressor','K-Nearest Neighbour','Supper Vector Machine'],
# ----> 2         'Accuracy':[Logistic_regression_Accuracy,Decison_tree_accuracy,Random_Forest_accuracy,KNN_accuracy,SVM_accuracy]}
#       3 scorecomparison=pd.DataFrame(scores)
#       4 scorecomparison
#
# NameError: name 'Logistic_regression_Accuracy' is not defined
