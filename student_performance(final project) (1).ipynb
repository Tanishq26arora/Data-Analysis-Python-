# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/tanis/Downloads/Student_Performance.csv")
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
df.shape
# Out:
# (10000, 6)

# %%
df.count()
# Out:
# Hours Studied                       10000
# Previous Scores                     10000
# Extracurricular Activities          10000
# Sleep Hours                         10000
# Sample Question Papers Practiced    10000
# Performance Index                   10000
# dtype: int64

# %%
df.min()
# Out:
# Hours Studied                          1
# Previous Scores                       40
# Extracurricular Activities            No
# Sleep Hours                            4
# Sample Question Papers Practiced       0
# Performance Index                   10.0
# dtype: object

# %%
df.max()
# Out:
# Hours Studied                           9
# Previous Scores                        99
# Extracurricular Activities            Yes
# Sleep Hours                             9
# Sample Question Papers Practiced        9
# Performance Index                   100.0
# dtype: object

# %%
df.isnull()
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0             False            False                       False        False
# 1             False            False                       False        False
# 2             False            False                       False        False
# 3             False            False                       False        False
# 4             False            False                       False        False
# ...             ...              ...                         ...          ...
# 9995          False            False                       False        False
# 9996          False            False                       False        False
# 9997          False            False                       False        False
# 9998          False            False                       False        False
# 9999          False            False                       False        False
#
# ...

# %%
df.isnull().sum()
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 127

# %%
df
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
df = df.drop(columns=['Sample Question Papers Practiced'])

# %%
df = df.drop(columns=['Extracurricular Activities'])
df
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  Performance Index
# 0                 7               99            9               91.0
# 1                 4               82            4               65.0
# 2                 8               51            7               45.0
# 3                 5               52            5               36.0
# 4                 7               75            8               66.0
# ...             ...              ...          ...                ...
# 9995              1               49            4               23.0
# 9996              7               64            8               58.0
# 9997              6               83            8               74.0
# 9998              9               97            7               95.0
# 9999              7               74            8               64.0
#
# [10000 rows x 4 columns]

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9995    False
# 9996     True
# 9997    False
# 9998     True
# 9999    False
# Length: 10000, dtype: bool

# %%
df
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  Performance Index
# 0                 7               99            9               91.0
# 1                 4               82            4               65.0
# 2                 8               51            7               45.0
# 3                 5               52            5               36.0
# 4                 7               75            8               66.0
# ...             ...              ...          ...                ...
# 9995              1               49            4               23.0
# 9996              7               64            8               58.0
# 9997              6               83            8               74.0
# 9998              9               97            7               95.0
# 9999              7               74            8               64.0
#
# [10000 rows x 4 columns]

# %%
df.duplicated().sum()
# Out:
# 1754

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  Performance Index
# 0                 7               99            9               91.0
# 1                 4               82            4               65.0
# 2                 8               51            7               45.0
# 3                 5               52            5               36.0
# 4                 7               75            8               66.0
# ...             ...              ...          ...                ...
# 9993              9               58            7               55.0
# 9994              6               46            8               39.0
# 9995              1               49            4               23.0
# 9997              6               83            8               74.0
# 9999              7               74            8               64.0
#
# [8246 rows x 4 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  Performance Index
# 0                 7               99            9               91.0
# 1                 4               82            4               65.0
# 2                 8               51            7               45.0
# 3                 5               52            5               36.0
# 4                 7               75            8               66.0
# ...             ...              ...          ...                ...
# 9993              9               58            7               55.0
# 9994              6               46            8               39.0
# 9995              1               49            4               23.0
# 9997              6               83            8               74.0
# 9999              7               74            8               64.0
#
# [8246 rows x 4 columns]

# %%
df=df.reset_index()

# %%
df
# Out:
#       index  Hours Studied  Previous Scores  Sleep Hours  Performance Index
# 0         0              7               99            9               91.0
# 1         1              4               82            4               65.0
# 2         2              8               51            7               45.0
# 3         3              5               52            5               36.0
# 4         4              7               75            8               66.0
# ...     ...            ...              ...          ...                ...
# 8241   9993              9               58            7               55.0
# 8242   9994              6               46            8               39.0
# 8243   9995              1               49            4               23.0
# 8244   9997              6               83            8               74.0
# 8245   9999              7               74            8               64.0
#
# [8246 rows x 5 columns]

# %%
df = df.drop(columns=['index'])

# %%
df
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  Performance Index
# 0                 7               99            9               91.0
# 1                 4               82            4               65.0
# 2                 8               51            7               45.0
# 3                 5               52            5               36.0
# 4                 7               75            8               66.0
# ...             ...              ...          ...                ...
# 8241              9               58            7               55.0
# 8242              6               46            8               39.0
# 8243              1               49            4               23.0
# 8244              6               83            8               74.0
# 8245              7               74            8               64.0
#
# [8246 rows x 4 columns]

# %%
sns.boxplot(x='Hours Studied',data=df)
# Out:
# <Axes: xlabel='Hours Studied'>

# %%
sns.scatterplot(x='Previous Scores',y='Performance Index',data=df)
# Out:
# <Axes: xlabel='Previous Scores', ylabel='Performance Index'>

# %%
sns.scatterplot(x='Previous Scores',y='Hours Studied',data=df)
# Out:
# <Axes: xlabel='Previous Scores', ylabel='Hours Studied'>

# %%
sns.scatterplot(x='Performance Index',y='Sleep Hours',data=df)
# Out:
# <Axes: xlabel='Performance Index', ylabel='Sleep Hours'>

# %%
sns.boxplot(x='Previous Scores',data=df)
# Out:
# <Axes: xlabel='Previous Scores'>

# %%
sns.boxplot(x='Sleep Hours',data=df)
# Out:
# <Axes: xlabel='Sleep Hours'>

# %%
sns.boxplot(x='Performance Index',data=df)
# Out:
# <Axes: xlabel='Performance Index'>

# %%
sns.regplot(x='Previous Scores',y='Performance Index',data=df)
# Out:
# <Axes: xlabel='Previous Scores', ylabel='Performance Index'>

# %%
sns.pairplot(df)
# Out:
# C:\Users\tanis\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\tanis\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\tanis\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
#independent and dependent of values
X=df.iloc[:,0:2]
Y=df.iloc[:,-1]

# %%
X
# Out:
#       Hours Studied  Previous Scores
# 0                 7               99
# 1                 4               82
# 2                 8               51
# 3                 5               52
# 4                 7               75
# ...             ...              ...
# 8241              9               58
# 8242              6               46
# 8243              1               49
# 8244              6               83
# 8245              7               74
#
# [8246 rows x 2 columns]

# %%
Y
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 8241    55.0
# 8242    39.0
# 8243    23.0
# 8244    74.0
# 8245    64.0
# Name: Performance Index, Length: 8246, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
#splitting the data
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# %%
#scaling the data
scaler=StandardScaler()
X_train=scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-0.76467427,  1.16947364],
#        [ 1.16637183,  0.76529184],
#        [-1.1508835 , -0.15855228],
#        ...,
#        [-1.1508835 ,  1.45817493],
#        [-0.76467427,  1.05399312],
#        [ 0.00774417,  0.41885029]])

# %%
X_test
# Out:
#       Hours Studied  Previous Scores
# 3332              6               80
# 7741              4               49
# 6020              3               56
# 6474              6               68
# 4404              2               97
# ...             ...              ...
# 5438              6               62
# 4382              9               97
# 5766              7               63
# 2098              2               49
# 4950              9               40
#
# [2062 rows x 2 columns]

# %%
X_test=scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.39395339,  0.59207107],
#        [-0.37846505, -1.19787692],
#        [-0.76467427, -0.79369511],
#        ...,
#        [ 0.78016261, -0.38951331],
#        [-1.1508835 , -1.19787692],
#        [ 1.55258106, -1.71753923]])

# %%
Y_train
# Out:
# 7009    73.0
# 1464    79.0
# 2991    41.0
# 6504    32.0
# 1192    31.0
#         ...
# 5734    76.0
# 5191    62.0
# 5390    77.0
# 860     69.0
# 7270    61.0
# Name: Performance Index, Length: 6184, dtype: float64

# %%
Y_test
# Out:
# 3332    73.0
# 7741    29.0
# 6020    36.0
# 6474    62.0
# 4404    74.0
#         ...
# 5438    51.0
# 4382    95.0
# 5766    54.0
# 2098    24.0
# 4950    33.0
# Name: Performance Index, Length: 2062, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
regression=LinearRegression(n_jobs=-1)

# %%
regression.fit(X_train,Y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
regression
# Out:
# LinearRegression(n_jobs=-1)

# %%
y_pred=regression.predict(X_test)

# %%
from sklearn.metrics import r2_score
score=r2_score(Y_test,y_pred)
print(score)
# Out:
# 0.9847521746530129

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
#postpruning technique
treemodel=DecisionTreeRegressor(max_depth=2)

# %%
#treemodel
treemodel.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor(max_depth=2)

# %%
#constructing a tree
import matplotlib.pyplot as plt
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(treemodel,filled=True)
# Out:
# [Text(0.5, 0.8333333333333334, 'x[1] <= 0.044\nsquared_error = 370.542\nsamples = 6184\nvalue = 55.483'),
#  Text(0.25, 0.5, 'x[1] <= -0.823\nsquared_error = 141.95\nsamples = 3159\nvalue = 40.525'),
#  Text(0.125, 0.16666666666666666, 'squared_error = 86.38\nsamples = 1609\nvalue = 32.83'),
#  Text(0.375, 0.16666666666666666, 'squared_error = 74.336\nsamples = 1550\nvalue = 48.514'),
#  Text(0.75, 0.5, 'x[1] <= 0.967\nsquared_error = 131.665\nsamples = 3025\nvalue = 71.102'),
#  Text(0.625, 0.16666666666666666, 'squared_error = 79.8\nsamples = 1627\nvalue = 64.297'),
#  Text(0.875, 0.16666666666666666, 'squared_error = 75.423\nsamples = 1398\nvalue = 79.021')]

# %%
#prediction
Y_pred=treemodel.predict(X_test)

# %%
Y_pred
# Out:
# array([64.29748002, 32.82970789, 48.51419355, ..., 48.51419355,
#        32.82970789, 32.82970789])

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
scoree = r2_score(Y_test, Y_pred)

# %%
print(scoree)
# Out:
# 0.7894090134923748

# %%
#prepruning
parameter={'criterion':['squared_error'],
          'splitter':['best','random'],
          'max_depth':[1,2,3,4,5],
          'max_features':['auto','sqrt','log2'],
          'ccp_alpha':[1,2,3,4,5,6,7]}

# %%
from sklearn.model_selection import GridSearchCV

# %%
treemodel=DecisionTreeRegressor()
cv=GridSearchCV(treemodel,param_grid=parameter,cv=5,
               scoring='r2')

# %%
cv.fit(X_train,Y_train)
# Out:
# C:\Users\tanis\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# C:\Users\tanis\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# C:\Users\tanis\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# C:\Users\tanis\anaconda3\Lib\site-packages\sklearn\tree\_classes.py:277: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features=1.0'`.
#   warnings.warn(
# ...

# %%
cv.best_params_
# Out:
# {'ccp_alpha': 1,
#  'criterion': 'squared_error',
#  'max_depth': 5,
#  'max_features': 'auto',
#  'splitter': 'best'}

# %%
cv.predict(X_test)
# Out:
# array([74.00421941, 29.25542169, 37.62732919, ..., 57.84834123,
#        29.25542169, 35.14226804])

# %%
Y_pred=cv.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
score1= r2_score(Y_pred,Y_test)
print(score1)
# Out:
# 0.9279607422590435

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np
# Assuming y_pred and y_test are your predicted and actual values respectively
mae = mean_absolute_error(Y_test, Y_pred)
mse = mean_squared_error(Y_test, Y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(Y_test, Y_pred)
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R² Score: {r2}")
# Out:
# Mean Absolute Error (MAE): 4.108633039394328
# Mean Squared Error (MSE): 25.41269392385606
# Root Mean Squared Error (RMSE): 5.041100467542385
# R² Score: 0.9324257873062151

# %%
#visualization
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
randomforest = RandomForestRegressor()

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split( X, Y, test_size=0.20, random_state=43)

# %%
from sklearn.model_selection import GridSearchCV

param_dist = {'max_depth': [2,3,4,5],
             'bootstrap':[True,False],
             'max_features': ['auto','sqrt','log2',None],
              'criterion':['squared_error']}

# %%
classifier_regressor = GridSearchCV(randomforest,
                                    param_grid = param_dist,
                                    cv=5,
                                   n_jobs=3)

# %%
randomforest.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
#prediction
Y_pred =randomforest.predict(X_test)
Y_pred
# Out:
# array([48.54034256, 70.92621658, 74.11156682, ..., 41.85630821,
#        61.52003082, 89.22210066])

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
score2 = r2_score(Y_pred,Y_test)
print(score2)
# Out:
# 0.9828652381074159

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
# Create and train the KNN regressor
knn_regressor = KNeighborsRegressor(n_neighbors=5)

# %%
# You can choose the number of neighbors
knn_regressor.fit(X_train, Y_train)
# Out:
# KNeighborsRegressor()

# %%
# Make predictions on the test set
y_pred = knn_regressor.predict(X_test)

# %%
mse = mean_squared_error(Y_test, y_pred)
score3= r2_score(Y_test, y_pred)

# %%
score3
# Out:
# 0.9818240588449557

# %%
print(f"Mean Squared Error: {mse:.2f}")
print(f"R^2 Score: {r2:.2f}")
# Out:
# Mean Squared Error: 6.80
# R^2 Score: 0.93

# %%
from sklearn.svm import SVR

# %%
# Create and train the SVM regressor
svm_regressor = SVR(kernel='linear', C=1)

# %%
 # You can choose different kernels and parameters
svm_regressor.fit(X_train, Y_train)
# Out:
# SVR(C=1, kernel='linear')

# %%
# Make predictions on the test set
y_pred = svm_regressor.predict(X_test)

# %%
# Evaluate the model
mse = mean_squared_error(Y_test, y_pred)
score4 = r2_score(Y_test, y_pred)
score4

# %%
print(f"Mean Squared Error: {mse:.2f}")
print(f"R^2 Score: {r2:.2f}")
# Out:
# Mean Squared Error: 5.77
# R^2 Score: 0.93

# %%
score4
# Out:
# 0.984583871814955

# %%
scores={'Model':['Linear Regression','Decision Tree Regressor','Random Forest Regressor','K-Nearest Neighbour','Supper Vector Machine'],
        'Accuracy':[score,score1,score2,score3,score4]}
scorecomparison=pd.DataFrame(scores)
scorecomparison
# Out:
#                      Model  Accuracy
# 0        Linear Regression  0.927961
# 1  Decision Tree Regressor  0.927961
# 2  Random Forest Regressor  0.982865
# 3      K-Nearest Neighbour  0.981824
# 4    Supper Vector Machine  0.984584
